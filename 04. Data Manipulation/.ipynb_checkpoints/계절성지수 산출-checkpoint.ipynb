# %%
import math
import numpy as np

# %%
import pandas as pd
from sqlalchemy import create_engine 
 
# DB 커넥션 열기
engine = create_engine('oracle+cx_oracle://kopo:kopo@192.168.110.112:1521/orcl') 
engine1 = create_engine('oracle+cx_oracle://KGY:kgy@192.168.110.24:1522/XE')
# DB 테이블을 읽어 Data Frame 변수에 저장하기
customerData = pd.read_sql_query('SELECT * FROM KOPO_CHANNEL_SEASONALITY_NEW', engine)

# %%
# 컬럼명 대문자
customerData.columns = [x.upper() for x in customerData.columns]

# %%
customerData=customerData.sort_values(["REGIONID","PRODUCT","YEARWEEK"], ascending=[True,True,True])

# %%
customerData["QTY"] = np.\
where(customerData["QTY"] <= 0, 1, customerData["QTY"])
customerData.head()
# Out:
#      REGIONID    PRODUCT YEARWEEK    QTY
# 298       A00  PRODUCT34   201401  661.0
# 1757      A00  PRODUCT34   201402  679.0
# 3125      A00  PRODUCT34   201403  578.0
# 205       A00  PRODUCT34   201404  532.0
# 4369      A00  PRODUCT34   201405  516.0

# %%
# 인덱스 다시 설정
sortedData = customerData.reset_index(drop=True)
sortedData.head(5)
# Out:
#   REGIONID    PRODUCT YEARWEEK    QTY
# 0      A00  PRODUCT34   201401  661.0
# 1      A00  PRODUCT34   201402  679.0
# 2      A00  PRODUCT34   201403  578.0
# 3      A00  PRODUCT34   201404  532.0
# 4      A00  PRODUCT34   201405  516.0

# %%
def sub_function(data):
    data = data.reset_index(drop=True)
    data["MA"]=data["QTY"].rolling(window=13,center=True).mean()
    
    suborder=math.floor(13/2)
   
    list=[]
    maxLength=len(data)-1
    for i in range(0,suborder):
        list.append(data['QTY'][0:i+suborder+1].mean())
        data.loc[i,"MA"]=list[i]
    
    list1=[]
    for i in range(0,suborder):
        list1.append(data['QTY'][-i-suborder-1:].mean())
        data['MA'][maxLength-i]=list1[i]
        
    return data

# %%
def smoo_function(data):
    data = data.reset_index(drop=True)
    data["SMOOTH"]=data["REFINE_QTY"].rolling(window=5,center=True).mean()
    
    suborder=math.floor(5/2)
   
    list=[]
    maxLength=len(data)-1
    for i in range(0,suborder):
        list.append(data['REFINE_QTY'][0:i+suborder+1].mean())
        data.loc[i,"SMOOTH"]=list[i]
    
    list1=[]
    for i in range(0,suborder):
        list1.append(data['REFINE_QTY'][-i-suborder-1:].mean())
        data['SMOOTH'][maxLength-i]=list1[i]
        
    return data

# %%
def std_function(data):
    data = data.reset_index(drop=True)
    data["STDEV"]=data["MA"].rolling(window=5,center=True).std()
    
    suborder=math.floor(5/2)
   
    list=[]
    maxLength=len(data)-1
    for i in range(0,suborder):
        list.append(data['MA'][0:i+suborder+1].std())
        data.loc[i,"STDEV"]=list[i]
    
    list1=[]
    for i in range(0,suborder):
        list1.append(data['MA'][-i-suborder-1:].std())
        data['STDEV'][maxLength-i]=list1[i]
        
    return data

# %%
groupResult = sortedData.groupby(['REGIONID','PRODUCT']).apply(sub_function)
aa=groupResult.reset_index(drop=True)

# %%
aa.head()
# Out:
#   REGIONID    PRODUCT YEARWEEK    QTY          MA
# 0      A00  PRODUCT34   201401  661.0  542.285714
# 1      A00  PRODUCT34   201402  679.0  520.000000
# 2      A00  PRODUCT34   201403  578.0  514.444444
# 3      A00  PRODUCT34   201404  532.0  516.800000
# 4      A00  PRODUCT34   201405  516.0  503.363636

# %%
bb = aa.groupby(['REGIONID','PRODUCT']).apply(std_function)
bb.head()
# Out:
#                      REGIONID    PRODUCT YEARWEEK    QTY          MA  \
# REGIONID PRODUCT
# A00      PRODUCT34 0      A00  PRODUCT34   201401  661.0  542.285714
#                    1      A00  PRODUCT34   201402  679.0  520.000000
#                    2      A00  PRODUCT34   201403  578.0  514.444444
#                    3      A00  PRODUCT34   201404  532.0  516.800000
#                    4      A00  PRODUCT34   201405  516.0  503.363636
#
#                           STDEV
# REGIONID PRODUCT
# A00      PRODUCT34 0  14.734617
#                    1  12.806131
#                    2  14.253036
#                    3  12.002994
#                    4  15.591135

# %%
bb["HIGH"]=bb["MA"]+bb["STDEV"]
bb["LOW"]=bb["MA"]-bb["STDEV"]

# %%
bb['REFINE_QTY']=np.where(bb['QTY']>bb['HIGH'],bb['HIGH'],\
        np.where(bb['QTY']<bb['LOW'],bb['LOW'],bb['QTY']))

# %%
cc = bb.groupby(['REGIONID','PRODUCT']).apply(smoo_function)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: 'REGIONID' is both a column name and an index level.
# Defaulting to column but this will raise an ambiguity error in a future version
#   """Entry point for launching an IPython kernel.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: 'PRODUCT' is both a column name and an index level.
# Defaulting to column but this will raise an ambiguity error in a future version
#   """Entry point for launching an IPython kernel.

# %%
dd=cc.reset_index(drop=True)
dd.head()
# Out:
#   REGIONID    PRODUCT YEARWEEK    QTY          MA      STDEV        HIGH  \
# 0      A00  PRODUCT34   201401  661.0  542.285714  14.734617  557.020331
# 1      A00  PRODUCT34   201402  679.0  520.000000  12.806131  532.806131
# 2      A00  PRODUCT34   201403  578.0  514.444444  14.253036  528.697481
# 3      A00  PRODUCT34   201404  532.0  516.800000  12.002994  528.802994
# 4      A00  PRODUCT34   201405  516.0  503.363636  15.591135  518.954771
#
#           LOW  REFINE_QTY      SMOOTH
# 0  527.551098  557.020331  539.507981
# 1  507.193869  532.806131  536.831734
# 2  500.191408  528.697481  532.665387
# 3  504.797006  528.802994  514.586876
# 4  487.772501  516.000000  497.704610

# %%
dd["STABLE"] = dd["QTY"]/dd["SMOOTH"]
dd["UNSTABLE"] = dd["REFINE_QTY"]/dd["SMOOTH"]
dd
# Out:
#        REGIONID    PRODUCT YEARWEEK      QTY           MA       STDEV  \
# 0           A00  PRODUCT34   201401    661.0   542.285714   14.734617
# 1           A00  PRODUCT34   201402    679.0   520.000000   12.806131
# 2           A00  PRODUCT34   201403    578.0   514.444444   14.253036
# 3           A00  PRODUCT34   201404    532.0   516.800000   12.002994
# 4           A00  PRODUCT34   201405    516.0   503.363636   15.591135
# 5           A00  PRODUCT34   201406    423.0   490.750000   24.122226
# 6           A00  PRODUCT34   201407    407.0   480.230769   31.835969
# 7           A00  PRODUCT34   201408    364.0   453.384615   37.577643
# 8           A00  PRODUCT34   201409    470.0   423.846154   40.469705
# 9           A00  PRODUCT34   201410    538.0   401.230769   39.050923
# 10          A00  PRODUCT34   201411    369.0   378.538462   36.567721
# 11          A00  PRODUCT34   201412    352.0   352.692308   35.529528
# 12          A00  PRODUCT34   201413    354.0   332.538462   33.564060
# 13          A00  PRODUCT34   201414    312.0   312.000000   34.314875
# 14          A00  PRODUCT34   201415    295.0   292.923077   40.540410
# 15          A00  PRODUCT34   201416    284.0   264.307692   43.641337
# 16          A00  PRODUCT34   201417    237.0   229.307692   43.686328
# 17          A00  PRODUCT34   201418    180.0   206.384615   39.767170
# 124646  5039.016380  4929.291312  4929.291312  5040.695576  0.795525  0.977899
# 124647  5172.674250  4876.864212  4876.864212  5033.724058  0.852649  0.968838
# 124648  5289.273978  4967.033714  5289.273978  5045.737340  1.141558  1.048266
# 124649  5587.923899  5105.922254  5105.922254  4953.729676  0.829476  1.030723
# 124650  5566.511210  5027.334944  5027.334944  4904.219976  0.918801  1.025104
# 124651  5019.516241  4469.252989  4469.252989  4811.861437  0.884273  0.928799
# 124652  5049.684284  4629.315716  4629.315716  4798.467248  0.744821  0.964749
# 124653  5002.336902  4827.481280  4827.481280  4784.153362  0.867865  1.009057
# 124654  5038.951309  4915.448691  5038.951309  4876.902764  1.042875  1.033228
# 124655  4955.765516  4824.678929  4955.765516  4979.114587  1.174104  0.995311
# 124656  5056.185645  4919.564355  4933.000000  5017.022913  0.983252  0.983252
# 124657  5140.374829  4973.053742  5140.374829  5009.713448  1.507272  1.026082
#
# [124658 rows x 12 columns]

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
dd.head()
# Out:
#   REGIONID    PRODUCT YEARWEEK    QTY          MA      STDEV        HIGH  \
# 0      A00  PRODUCT34   201401  661.0  542.285714  14.734617  557.020331
# 1      A00  PRODUCT34   201402  679.0  520.000000  12.806131  532.806131
# 2      A00  PRODUCT34   201403  578.0  514.444444  14.253036  528.697481
# 3      A00  PRODUCT34   201404  532.0  516.800000  12.002994  528.802994
# 4      A00  PRODUCT34   201405  516.0  503.363636  15.591135  518.954771
#
#           LOW  REFINE_QTY      SMOOTH    STABLE  UNSTABLE
# 0  527.551098  557.020331  539.507981  1.225190  1.032460
# 1  507.193869  532.806131  536.831734  1.264828  0.992501
# 2  500.191408  528.697481  532.665387  1.085109  0.992551
# 3  504.797006  528.802994  514.586876  1.033839  1.027626
# 4  487.772501  516.000000  497.704610  1.036760  1.036760

# %%
dd.columns=["AA","BB","CC","DD","EE","FF","GG","HH","II","JJ","KK","LL"]

# %%
dd.tail()
# Out:
#          AA         BB      CC      DD           EE         FF           GG  \
# 124653  A77  PRODUCT12  201648  4152.0  4914.909091  87.427811  5002.336902
# 124654  A77  PRODUCT12  201649  5086.0  4977.200000  61.751309  5038.951309
# 124655  A77  PRODUCT12  201650  5846.0  4890.222222  65.543294  4955.765516
# 124656  A77  PRODUCT12  201651  4933.0  4987.875000  68.310645  5056.185645
# 124657  A77  PRODUCT12  201652  7551.0  5056.714286  83.660544  5140.374829
#
#                  HH           II           JJ        KK        LL
# 124653  4827.481280  4827.481280  4784.153362  0.867865  1.009057
# 124654  4915.448691  5038.951309  4876.902764  1.042875  1.033228
# 124655  4824.678929  4955.765516  4979.114587  1.174104  0.995311
# 124656  4919.564355  4933.000000  5017.022913  0.983252  0.983252
# 124657  4973.053742  5140.374829  5009.713448  1.507272  1.026082

# %%
dd.to_csv("d:/ddTest.csv")

# %%
import matplotlib.pyplot as plt

# %%
sns.lmplot(x='STABLE',y='UNSTABLE', data = dd, fit_reg=False)

# %%
engine_oracle = create_engine('oracle+cx_oracle://KGY:kgy@192.168.110.24:1522/XE')

# %%
# 데이터 저장
resultname='KOPO_CHANNEL_TEST_RESULT_HK'
dd.to_sql(resultname, engine_oracle, if_exists='replace', index=False)

# %%
len(dd)
# Out:
# 124658

# %%
a=3
a
